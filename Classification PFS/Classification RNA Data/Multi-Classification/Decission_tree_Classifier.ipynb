# %% [markdown]
# # Classification model using Decision Tree

# %% [markdown]
# ### 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### 2. Upload RNA data

# %%
path ='../../../Data_preprocessing/Prediction PFS/RNA+Clinic joined/New/Clinical_data_and_RNA_total_Features_PFS.csv'
data = pd.read_csv(path)
data.head(5)
# Out:
#    Unnamed: 0                                RNA_ID   Age  Sarc  Rhab  \
# 0           0  G138701_RCCBMS-00020-T_v1_RNA_OnPrem  62.0   0.0   0.0
# 1           1  G138701_RCCBMS-00097-T_v1_RNA_OnPrem  67.0   0.0   0.0
# 2           2  G138701_RCCBMS-00141-T_v1_RNA_OnPrem  62.0   0.0   0.0
# 3           3  G138701_RCCBMS-00099-T_v1_RNA_OnPrem  60.0   0.0   0.0
# 4           4  G138701_RCCBMS-00163-T_v1_RNA_OnPrem  76.0   0.0   0.0
#
#    Number_of_Prior_Therapies  \
# 0                        2.0
# 1                        2.0
# 2                        1.0
# 3                        3.0
# 4                        2.0
#
#    Days_from_TumorSample_Collection_and_Start_of_Trial_Therapy  \
# 0                                              962.0
# 1                                              254.0
# 2                                              800.0
# 3                                              790.0
# 4                                             1241.0
#
#    Tumor_Shrinkage        PFS  TM_TC_Ratio  ...    ZWILCH     ZWINT      ZXDA  \
# 0       -16.406250  12.164384     0.766909  ...  33.26816  30.04056  30.36292
# 1       -40.000000   5.490411     0.773269  ...  31.53633  29.94062  30.80829
# 2       -89.436620  61.906849     1.782859  ...  30.74474  31.95812  30.73898
# 3        11.787072   1.249315     5.890573  ...  31.63196  30.71732  31.09654
# 4         0.000000   5.654795     1.374775  ...  31.75620  30.75149  30.55896
#
#        ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# 0  30.98129  32.38442  28.01561  31.24379  33.81903  33.22469  31.23383
# 1  30.74475  32.09470  26.32526  32.70057  33.67262  33.10198  32.44643
# 2  30.15898  31.69473  26.33098  32.68330  33.96047  32.97135  32.20607
# 3  30.25757  31.90774  27.53819  32.64194  34.54254  33.24885  32.78278
# 4  30.17101  31.01545  21.45312  32.86620  34.24375  34.86720  32.73361
#
# [5 rows x 43920 columns]

# %%
X = data.iloc[:,27:43921  ] 
Y = [] # Target column
# For each entry I classified it by its PFS value.
for i in range (len(data)):
    if data.PFS[i]<3: # If PFS is lower than 3 months, I will consider it as NonResponder (NR)
        Y.append(0)
    elif data.PFS[i]<6:
        Y.append(1)
    else:
        Y.append(2)# If PFS is over 3 months, I will consider it as Responder (R)

X
# Out:
#        5S_rRNA        7SK       A1BG   A1BG-AS1       A1CF        A2M  \
# 0    21.038652  35.199603  30.187983  22.999432  33.643965  37.130851
# 1    21.038652  38.183943  30.483638  25.581769  28.866645  37.945043
# 2    21.038652  37.141292  30.092851  26.933385  26.684228  36.851946
# 3    21.038652  36.447015  30.975010  26.683128  32.521495  38.453517
# 4    21.038652  37.623923  26.915750  22.999432  23.219176  38.931987
# ..         ...        ...        ...        ...        ...        ...
# 176  21.038043  36.338729  30.954407  27.310879  26.161567  38.376185
# 177  21.038043  38.248915  33.110149  26.793199  26.161567  36.537388
# 178  21.038043  35.884812  32.880283  25.659842  31.822942  38.265866
# 179  21.038043  35.283776  30.658715  27.533890  32.930512  36.882090
# 180  21.038043  36.694546  27.118678  17.788726  33.128697  35.626724
#
#        A2M-AS1      A2ML1  A2ML1-AS1      A2MP1  ...    ZWILCH     ZWINT  \
# 0    22.705126  22.869853  21.076515  21.271282  ...  33.26816  30.04056
# 1    27.797609  24.142100  21.076515  21.271282  ...  31.53633  29.94062
# 2    22.705126  30.406352  21.076515  21.271282  ...  30.74474  31.95812
# 3    26.337846  28.229357  21.076515  21.271282  ...  31.63196  30.71732
# 4    22.705126  22.869853  21.076515  21.271282  ...  31.75620  30.75149
# ..         ...        ...        ...        ...  ...       ...       ...
# 176  25.971821  24.438322  21.076088  21.056491  ...  31.62442  30.78532
# 177  26.388265  24.438322  21.076088  21.056491  ...  31.40147  31.50200
# 178  26.504307  24.438322  21.076088  21.056491  ...  31.21094  30.91066
# 179  26.303147  24.438322  21.076088  21.056491  ...  31.12324  28.76312
# 180  20.654847  24.438322  21.076088  21.056491  ...  32.79170  33.26885
#
#          ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# 0    30.36292  30.98129  32.38442  28.01561  31.24379  33.81903  33.22469
# 1    30.80829  30.74475  32.09470  26.32526  32.70057  33.67262  33.10198
# 2    30.73898  30.15898  31.69473  26.33098  32.68330  33.96047  32.97135
# 3    31.09654  30.25757  31.90774  27.53819  32.64194  34.54254  33.24885
# 4    30.55896  30.17101  31.01545  21.45312  32.86620  34.24375  34.86720
# ..        ...       ...       ...       ...       ...       ...       ...
# 176  30.86517  30.92600  31.53239  23.65585  32.42073  34.41045  33.21697
# 177  29.96535  30.21446  31.49627  28.04168  32.19568  32.69615  32.18970
# 178  31.35764  30.99788  31.45772  23.65585  32.36832  35.02409  34.26388
# 179  31.48891  30.27351  32.88316  23.65585  31.76924  34.07224  34.35116
# 180  31.30271  30.72641  31.65005  23.65585  30.82798  34.72915  33.65903
#
#          ZZZ3
# 0    31.23383
# 1    32.44643
# 2    32.20607
# 3    32.78278
# 4    32.73361
# ..        ...
# 176  32.22166
# 177  32.59554
# 178  32.82148
# 179  31.98965
# 180  32.91379
#
# [181 rows x 43893 columns]

# %% [markdown]
# ### 3. Train-Test dataset split

# %%
XTrain, XTest, yTrain, yTest = train_test_split(X, Y, test_size=0.20, random_state=125, stratify=Y)
# Convert sets to arrays

XTrain = XTrain.values
XTest = XTest.values

print('Training set size:', len(XTrain))
print('Target column size of the training set:', len(yTrain))
print('Test set size:', len(XTest))
print('Target column size of the test set:', len(yTest))
# Out:
# Training set size: 144
# Target column size of the training set: 144
# Test set size: 37
# Target column size of the test set: 37

# %% [markdown]
# ### 4. Select the parameters of the model and fit it

# %%
param_grid = {'min_samples_leaf': [2,5,7],
              'min_samples_split': [2, 5],
              'max_depth':[2,5,10,12],
              'criterion':['entropy','gini'],
              'splitter': ['best', 'random'],
              'random_state':[125]}

# Creamos un GridSearchCV que permite evaluar y seleccionar de forma sistemática los parámetros de nuestro modelo. 
# Indicándole un modelo y los parámetros a probar, puede evaluar el rendimiento del primero en función de los 
# segundos mediante validación cruzada.
clf = GridSearchCV(DecisionTreeClassifier(), param_grid, cv = 5)

clf.fit(XTrain , yTrain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [2, 5, 10, 12],
#                          'min_samples_leaf': [2, 5, 7],
#                          'min_samples_split': [2, 5], 'random_state': [125],
#                          'splitter': ['best', 'random']})

# %%
print("Best estimate of parameters according to GridSearchCV:")
model = clf.best_estimator_
# Fit the model with the best parameters
model.fit(XTrain , yTrain)
# Out:
# Best estimate of parameters according to GridSearchCV:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=2,
#                        random_state=125, splitter='random')

# %%
print("Best result of the cross validation of the model with the best paramters:" +str(clf.best_score_))
# Out:
# Best result of the cross validation of the model with the best paramters:0.46551724137931033

# %% [markdown]
# ### 5. Prediction

# %%
# Making predictions with the optimal model on the training dataset
yhatTrain = model.predict(XTrain)
contTrain = 0

# Comparing with the Target column and check how many hits there have been
for i in range(0,len(yTrain),1) :
    if (yhatTrain[i] == yTrain[i]):
        contTrain = contTrain + 1

# %%
# Making predictions with the optimal model on the test dataset
yhatTest = model.predict(XTest)
contTest = 0

# Comparing with the Target column and check how many hits there have been
for i in range(0,len(yTest),1) :
    if (yhatTest[i] == yTest[i]):
        contTest = contTest + 1

# %% [markdown]
# ### 6. Results

# %%
print('Final accuracy on the training dataset:' + str(contTrain/len(yTrain)))
print('Final accuracy on the testing dataset: ' + str(contTest/len(yTest)))
# Out:
# Final accuracy on the training dataset:0.8888888888888888
# Final accuracy on the testing dataset: 0.5405405405405406

# %%
from sklearn.metrics import classification_report,confusion_matrix

print('----------------Confusion Matrix (Training)------------------')
print(confusion_matrix(yTrain,yhatTrain))
print('Input data:  ' + str(np.array(yTrain)))
print('Prediction:        ' +str(yhatTrain))
# Out:
# ----------------Confusion Matrix (Training)------------------
# [[55  0 12]
#  [ 0 25  0]
#  [ 2  2 48]]
# Input data:  [1 0 2 0 2 2 0 0 2 0 2 0 1 0 2 2 0 2 2 2 0 0 0 2 0 0 0 0 1 1 2 2 2 2 0 1 2
#  0 0 2 1 2 2 1 0 0 2 2 1 0 0 0 2 0 0 2 0 2 1 2 0 2 1 0 0 0 0 2 2 2 0 2 0 0
#  0 2 0 2 0 0 0 1 2 0 0 1 2 2 1 1 0 2 0 2 0 0 1 0 1 0 0 2 0 0 2 2 2 1 0 2 2
#  1 2 0 1 0 0 0 2 0 1 0 2 0 0 2 1 1 0 0 0 2 0 1 0 0 0 2 2 2 1 2 0 1]
# Prediction:        [1 2 2 0 0 2 0 0 2 0 2 0 1 0 2 2 0 2 2 2 2 0 0 2 0 0 2 0 1 1 2 2 2 1 0 1 2
#  2 0 2 1 1 2 1 2 0 2 2 1 0 0 2 2 0 0 2 2 2 1 2 0 2 1 0 0 0 0 2 2 2 0 2 0 2
#  0 2 0 2 0 0 0 1 2 0 0 1 2 2 1 1 0 2 2 2 0 0 1 0 1 0 2 2 0 0 2 2 2 1 0 2 2
#  1 2 0 1 0 0 0 2 0 1 0 2 0 2 2 1 1 0 0 0 0 2 1 0 0 0 2 2 2 1 2 0 1]

# %%
print(classification_report(yTrain,yhatTrain))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89        67
#            1       0.93      1.00      0.96        25
#            2       0.80      0.92      0.86        52
#
#     accuracy                           0.89       144
#    macro avg       0.90      0.91      0.90       144
# weighted avg       0.90      0.89      0.89       144

# %%
print('----------------Confusion Matrix (Test)------------------')
print(confusion_matrix(yTest,yhatTest))
print('Input data:  ' + str(np.array(yTest)))
print('Prediction:        ' +str(yhatTest))
# Out:
# ----------------Confusion Matrix (Test)------------------
# [[10  1  7]
#  [ 1  0  5]
#  [ 3  0 10]]
# Input data:  [0 1 0 2 0 2 1 0 1 0 2 2 1 2 2 0 1 2 0 0 0 2 1 0 0 2 0 2 2 0 0 0 2 2 0 0 0]
# Prediction:        [0 2 2 2 2 2 2 2 0 0 2 2 2 2 0 1 2 0 0 0 0 2 2 2 0 2 0 2 2 0 0 0 2 0 2 2 2]

# %%
print(classification_report(yTest,yhatTest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.63        18
#            1       0.00      0.00      0.00         6
#            2       0.45      0.77      0.57        13
#
#     accuracy                           0.54        37
#    macro avg       0.39      0.44      0.40        37
# weighted avg       0.51      0.54      0.50        37

# %% [markdown]
# ### 7. Result visualization

# %%
X = data.iloc[1:,2:43895] 
print(X)
cols = []
for i in X:
    if i!= 'Target_uniclass' and i!= 'Target_multiclass':
        cols.append(i)
# Out:
#       Age  Sarc  Rhab  Number_of_Prior_Therapies  \
# 1    67.0   0.0   0.0                        2.0
# 2    62.0   0.0   0.0                        1.0
# 3    60.0   0.0   0.0                        3.0
# 4    76.0   0.0   0.0                        2.0
# 5    46.0   0.0   0.0                        3.0
# ..    ...   ...   ...                        ...
# 176  77.0   0.0   0.0                        1.0
# 177  54.0   0.0   0.0                        1.0
# 178  64.0   0.0   0.0                        1.0
# 179  75.0   0.0   0.0                        1.0
# 180  50.0   0.0   0.0                        1.0
#
#      Days_from_TumorSample_Collection_and_Start_of_Trial_Therapy  \
# 1                                                254.0
# 2                                                800.0
# 3                                                790.0
# 4                                               1241.0
# 5                                               2273.0
# ..                                                 ...
# 176                                               42.0
# 177                                               42.0
# 178                                               42.0
# 179                                               42.0
# 180                                               42.0
#
#      Tumor_Shrinkage        PFS  TM_TC_Ratio  Cohort_CM-009  Cohort_CM-010  \
# 1         -40.000000   5.490411     0.773269              0              1
# 2         -89.436620  61.906849     1.782859              0              1
# 3          11.787072   1.249315     5.890573              0              1
# 4           0.000000   5.654795     1.374775              0              1
# 5          -2.479339  15.419178     1.374775              0              1
# ..               ...        ...          ...            ...            ...
# 176        11.000000   1.906849     1.374775              1              0
# 177        57.000000   1.183562     1.374775              1              0
# 178       -43.000000  16.438356     1.374775              1              0
# 179        12.000000   1.216438     1.374775              1              0
# 180         0.000000   1.347945     1.374775              1              0
#
#      ...   ZSCAN26   ZSCAN29   ZSCAN30   ZSCAN31   ZSCAN32    ZSCAN4  \
# 1    ...  31.26734  30.92363  31.44693  31.88035  30.93113  22.02469
# 2    ...  32.06676  31.71804  30.80685  33.20725  30.37295  31.70408
# 3    ...  32.00628  31.50675  32.15519  32.40480  30.66563  22.02469
# 4    ...  31.33626  31.20889  31.42577  32.63856  32.34518  22.02469
# 5    ...  32.11192  31.93972  31.26535  31.17342  31.79837  22.02469
# ..   ...       ...       ...       ...       ...       ...       ...
# 176  ...  32.53348  31.49460  32.13513  31.04390  31.61227  21.82186
# 177  ...  33.00769  31.22918  30.28786  33.61109  31.33173  21.82186
# 178  ...  31.25735  32.25135  30.99271  30.19607  31.32072  21.82186
# 179  ...  31.50255  32.53577  31.74353  31.79814  31.16672  27.44984
# 180  ...  31.64318  31.36503  31.26613  28.33535  31.35287  21.82186
#
#       ZSCAN5A   ZSCAN5B   ZSCAN5C   ZSCAN5D
# 1    29.92504  29.27301  25.63381  29.13599
# 2    30.21397  29.06719  21.66871  27.61642
# 3    28.32372  24.01564  21.66871  23.11742
# 4    28.75105  21.64163  34.06657  23.11742
# 5    29.17998  21.64163  21.66871  28.74705
# ..        ...       ...       ...       ...
# 176  30.43850  22.83467  22.02240  25.46535
# 177  28.07117  22.83467  22.02240  25.46535
# 178  28.07952  22.83467  22.02240  25.46535
# 179  31.97006  22.83467  22.02240  25.46535
# 180  28.02187  22.83467  22.02240  25.46535
#
# [180 rows x 43893 columns]

# %%
from sklearn.tree import export_text

texto_modelo = export_text(
                    decision_tree = model,
                    feature_names = cols
               )
print(texto_modelo)
# Out:
# |--- OR10G6 <= 21.21
# |   |--- C6orf226 <= 22.44
# |   |   |--- GDAP1 <= 32.17
# |   |   |   |--- ITGAD <= 25.46
# |   |   |   |   |--- SUV39H2 <= 23.90
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- SUV39H2 >  23.90
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- ITGAD >  25.46
# |   |   |   |   |--- COX20P1 <= 22.03
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- COX20P1 >  22.03
# |   |   |   |   |   |--- class: 0
# |   |   |--- GDAP1 >  32.17
# |   |   |   |--- DNM1P32 <= 33.81
# |   |   |   |   |--- AC093388.3 <= 20.01
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- AC093388.3 >  20.01
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- DNM1P32 >  33.81
# |   |   |   |   |--- class: 1
# |   |--- C6orf226 >  22.44
# |   |   |--- WDR45BP1 <= 31.92
# |   |   |   |--- class: 0
# |   |   |--- WDR45BP1 >  31.92
# |   |   |   |--- class: 0
# |--- OR10G6 >  21.21
# |   |--- PSME4 <= 34.10
# |   |   |--- OLA1P1 <= 25.48
# |   |   |   |--- RP11-203B7.2 <= 24.52
# |   |   |   |   |--- ZNF570 <= 24.94
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- ZNF570 >  24.94
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- RP11-203B7.2 >  24.52
# |   |   |   |   |--- class: 1
# |   |   |--- OLA1P1 >  25.48
# |   |   |   |--- class: 0
# |   |--- PSME4 >  34.10
# |   |   |--- RAB28P1 <= 33.46
# |   |   |   |--- class: 2
# |   |   |--- RAB28P1 >  33.46
# |   |   |   |--- CIB4 <= 29.77
# |   |   |   |   |--- HACD4 <= 21.64
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- HACD4 >  21.64
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- CIB4 >  29.77
# |   |   |   |   |--- class: 2

# %%
from sklearn.tree import plot_tree

fig, ax = plt.subplots(figsize=(20, 15))

print(f"Tree depth: {model.get_depth()}")
print(f"Number of terminal nodes : {model.get_n_leaves()}")

plot = plot_tree(
            decision_tree = model,
            feature_names = cols,
            class_names   = ['Less than 3 months','Between 3 and 6 months','Over 6 months'],
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Tree depth: 5
# Number of terminal nodes : 17
