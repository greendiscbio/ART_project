# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("output_data.csv")
data
# Out:
#       5S_rRNA       7SK      A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1  \
# 0    0.716941  0.875897  0.771572  0.851082  0.799575  0.971229  0.886870
# 1    0.714991  0.923724  0.876746  0.677136  0.911125  0.960404  0.930377
# 2    0.714991  0.923281  0.875606  0.795155  0.794724  0.964062  0.788767
# 3    0.716540  0.900076  0.867027  0.804440  0.934921  0.991581  0.863431
# 4    0.714991  0.927947  0.823774  0.677136  0.815053  0.998077  0.798137
# ..        ...       ...       ...       ...       ...       ...       ...
# 139  0.714991  0.922710  0.855274  0.799161  0.944088  0.949768  0.897639
# 140  0.714991  0.884758  0.886210  0.677136  0.878778  0.958581  0.716506
# 141  0.714991  0.897219  0.807814  0.864388  0.796982  0.942862  0.874322
# 142  0.716941  0.913780  0.912505  0.842889  0.890190  0.982999  0.885090
# 143  0.716540  0.920280  0.887383  0.849271  0.875380  0.994183  0.883635
#
#         A2ML1  A2ML1-AS1     A2MP1  ...    ZWILCH     ZWINT      ZXDA  \
# ...

# %%
pfs = pd.read_csv("../Data_preprocessing/Prediction PFS/RNA+Clinic joined/Clinical_data_and_RNA_total_Features_PFS.csv")
pfs
# Out:
#      Unnamed: 0  Cohort                                RNA_ID  Sex  Age  \
# 0             0       1              P66432-07E-Run1_S20_L002    1 -1.0
# 1             1       1              P66451-08H-Run1_S26_L002    1 -1.0
# 2             2       1              P66291-06C-Run1_S26_L002    1 -1.0
# 3             3       1                              EA595529    0 -1.0
# 4             4       1              P66425-10B-Run1_S14_L001    1 -1.0
# ..          ...     ...                                   ...  ...  ...
# 176         176       1                              EA595597    0 -1.0
# 177         177       1               P66282-01G-Run1_S3_L001    1 -1.0
# 178         178       1               P66287-07B-Run1_S2_L001    0 -1.0
# 179         179       1               P66291-01B-Run1_S2_L001    0 -1.0
# 180         180       0  G138701_RCCBMS-00141-T_v1_RNA_OnPrem    0 -1.0
#
#      MSKCC  IMDC  Sarc  Rhab  Sarc_or_Rhab  ...    ZWILCH     ZWINT      ZXDA  \
# ...

# %%
# data.insert(0, "PFS", pfs.PFS)
data.insert(0, "RNA_ID", pfs.RNA_ID)

# %%
data
# Out:
#                                    RNA_ID   5S_rRNA       7SK      A1BG  \
# 0                P66432-07E-Run1_S20_L002  0.716941  0.875897  0.771572
# 1                P66451-08H-Run1_S26_L002  0.714991  0.923724  0.876746
# 2                P66291-06C-Run1_S26_L002  0.714991  0.923281  0.875606
# 3                                EA595529  0.716540  0.900076  0.867027
# 4                P66425-10B-Run1_S14_L001  0.714991  0.927947  0.823774
# ..                                    ...       ...       ...       ...
# 139                              EA632802  0.714991  0.922710  0.855274
# 140               P66507-04D-Run1_S3_L001  0.714991  0.884758  0.886210
# 141  G138701_RCCBMS-00028-T_v1_RNA_OnPrem  0.714991  0.897219  0.807814
# 142              P66425-06G-Run1_S30_L002  0.716941  0.913780  0.912505
# 143  G138701_RCCBMS-00113-T_v1_RNA_OnPrem  0.716540  0.920280  0.887383
#
#      A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1  A2ML1-AS1  ...  \
# ...

# %%
data.to_csv("Autoencoder_data.csv")
