# %% [markdown]
# #Import libraies and packages

# %%
pip install ray torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.1.0-cp37-cp37m-manylinux2014_x86_64.whl (59.1 MB)
#      |████████████████████████████████| 59.1 MB 1.3 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.13.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from ray) (4.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray) (6.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.7/dist-packages (from ray) (1.50.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray) (22.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray) (3.19.6)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.7/dist-packages (from ray) (1.3.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray) (2.23.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.7/dist-packages (from ray) (1.3.1)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.16.7-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 38.1 MB/s
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.32.0->ray) (1.15.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 17.4 MB/s
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.7/dist-packages (from virtualenv>=20.0.24->ray) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv>=20.0.24->ray) (3.10.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray) (5.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ray) (2.10)
# Installing collected packages: platformdirs, distlib, virtualenv, ray
# Successfully installed distlib-0.3.6 platformdirs-2.5.4 ray-2.1.0 virtualenv-20.16.7

# %%
pip install bayesian-optimization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-1.3.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.0.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.1.0)
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.3.1

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import pandas as pd
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest import ConcurrencyLimiter
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
#   if sys.path[0] == '':

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Model

# %%
import tensorflow as tf

def ConvNet(config, len_classes=2):
    input = tf.keras.layers.Input(shape=(43893, 1))
    x = input
    x = tf.keras.layers.Conv1D(filters=config['conv_block1_filters'], kernel_size=(8), strides=1)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    if config['fc_layer_type'] == 'dense':
        if config['pool_type'] == 'max':
            x = tf.keras.layers.GlobalMaxPooling1D()(x)
        else:
            x = tf.keras.layers.GlobalAveragePooling1D()(x)

        # Fully connected layer 1
        x = tf.keras.layers.Dense(units=config['fc1_units'])(x)
        x = tf.keras.layers.Dropout(config['dropout_rate'])(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('relu')(x)

        # Fully connected layer 2
        x = tf.keras.layers.Dense(units=len_classes)(x)
        x = tf.keras.layers.Dropout(config['dropout_rate'])(x)
        x = tf.keras.layers.BatchNormalization()(x)
        predictions = tf.keras.layers.Dense(1,tf.keras.layers.Activation('sigmoid'))(x)

    else:
        # Fully connected layer 1
        x = tf.keras.layers.Conv1D(filters=config['fc1_units'], kernel_size=1, strides=1)(x)
        x = tf.keras.layers.Dropout(config['dropout_rate'])(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('relu')(x)


        # Fully connected layer 2
        x = tf.keras.layers.Conv1D(filters=len_classes, kernel_size=1, strides=1)(x)
        x = tf.keras.layers.Dropout(config['dropout_rate'])(x)
        x = tf.keras.layers.BatchNormalization()(x)
        
        if config['pool_type'] == 'max':
            x = tf.keras.layers.GlobalMaxPooling1D()(x)
        else:
            x = tf.keras.layers.GlobalAveragePooling1D()(x)
        
        predictions = tf.keras.layers.Dense(1,tf.keras.layers.Activation('sigmoid'))(x)

    model = tf.keras.Model(inputs=input, outputs=predictions)
    
    print(model.summary())
    print(f'Total number of layers: {len(model.layers)}')

    return model

# %% [markdown]
# ## Metrics

# %%
from keras import backend as K
import random


def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## Training function

# %%
from sklearn import preprocessing

def train_mnist(config):
  path ='/content/drive/MyDrive/ART_Inv/CNN/Ray_Tune/Clinical_data_and_RNA_total_Features_PFS.csv'
  data_frame = pd.read_csv(path)
  
  from sklearn.model_selection import train_test_split
  X = data_frame.iloc[:,28:43921  ]   
  Y=[]
  for i in range (len(data_frame)):
      if data_frame.PFS[i]<3: # If PFS is lower than 3 months, I will consider it as NonResponder (NR)
          Y.append(0)
      else:
          Y.append(1)# If PFS is over 3 months, I will consider it as Responder (R)
  scaler = preprocessing.MinMaxScaler()
  names = X.columns
  d = scaler.fit_transform(X)
  X = pd.DataFrame(d, columns=names)
  XTrain, XTest, yTrain, yTest = train_test_split(X, Y, test_size=0.10, stratify = Y)
  # Convert sets to arrays
  XTrain = XTrain.values
  XTest = XTest.values
  # It is mandatory to transform Y list into array for trainning the model
  yTrain=np.array(yTrain)
  yTest=np.array(yTest)

  X_train = XTrain.reshape(XTrain.shape[0], 43893 , 1)
  X_test = XTest.reshape(XTest.shape[0], 43893, 1)
  X_train = X_train.astype('float32')
  X_test = X_test.astype('float32')
  # Create model
  model = ConvNet(config)

  # Compile model with losses and metrics
  model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate =config['lr']),
                  loss='binary_crossentropy',
                  metrics=['accuracy', f1_m,precision_m, recall_m
                           ])

  # Start model training
  history_m = model.fit(X_train, yTrain,
                      epochs=100,
                      validation_data=(X_test, yTest))

  history_m = {
  "loss": history_m.history["loss"][0],
  "val_loss": history_m.history["val_loss"][0],
  "accuracy": history_m.history["accuracy"][0],
  "val_accuracy": history_m.history["val_accuracy"][0]
  }
  return history_m

# %% [markdown]
# # Bayesian Optimization

# %%
pip install hpbandster ConfigSpace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hpbandster
#   Downloading hpbandster-0.7.4.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 117 kB/s
# Collecting ConfigSpace
#   Downloading ConfigSpace-0.6.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 50.7 MB/s
# Collecting Pyro4
#   Downloading Pyro4-4.82-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 10.1 MB/s
# Collecting serpent
#   Downloading serpent-1.41-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.12.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.7.3)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.32)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (4.1.1)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels->hpbandster) (2022.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels->hpbandster) (1.15.0)
# Building wheels for collected packages: hpbandster
#   Building wheel for hpbandster (setup.py) ... done
#   Created wheel for hpbandster: filename=hpbandster-0.7.4-py3-none-any.whl size=80009 sha256=a324637418df12ac83df4aa28e9307a6df4e7b656b41c2332f2eb39b95f91737
#   Stored in directory: /root/.cache/pip/wheels/d9/88/fc/61ab6b9f386a386839668631c39a6dc3c2fb0ec7000d552faa
# Successfully built hpbandster
# Installing collected packages: serpent, Pyro4, netifaces, ConfigSpace, hpbandster
# Successfully installed ConfigSpace-0.6.0 Pyro4-4.82 hpbandster-0.7.4 netifaces-0.11.0 serpent-1.41

# %%
pip install ConfigSpace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ConfigSpace in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.32)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (1.7.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (1.21.6)

# %%
import ConfigSpace as CS
config_space = CS.ConfigurationSpace()

# %%
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter(
        name="lr", choices=[0.01]))
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter(
        name="dropout_rate", choices=[ 0.3])) 
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter(
        name="conv_block1_filters", choices=[8]))
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter(
        name="fc_layer_type", choices= ['dense']))
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter(
        name="pool_type", choices= [ 'average']))
config_space.add_hyperparameter(
    CS.CategoricalHyperparameter(
        name="fc1_units", choices=[16]))
# Out:
# fc1_units, Type: Categorical, Choices: {16}, Default: 16

# %%
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.suggest.bohb import TuneBOHB
algo = TuneBOHB(
    config_space, metric="val_accuracy", mode="max", max_concurrent=1)
bohb = HyperBandForBOHB(
    time_attr="training_iteration",
    metric="val_accuracy",
      mode="max",
      max_t=2)
for i in range(10):
  tune.run(train_mnist, scheduler=bohb, num_samples=1, search_alg=algo)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The module `ray.tune.suggest.bohb` has been moved to `ray.tune.search.bohb` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bohb` with `ray.tune.search.bohb`.
#
# 2022-11-17 15:40:57,091	INFO worker.py:1528 -- Started a local Ray instance.
# 2022-11-17 15:40:59,491	WARNING function_trainable.py:587 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# 2022-11-17 15:40:59,538	INFO tensorboardx.py:170 -- pip install "ray[tune]" to see TensorBoard files.
# 2022-11-17 15:40:59,542	WARNING callback.py:109 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2022-11-17 15:44:22</td></tr>
# <tr><td>Running for: </td><td>00:03:22.67        </td></tr>
# <tr><td>Memory:      </td><td>2.2/12.7 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=0 total_brackets=2<br>Round #0:<br>  Bracket(Max Size (n)=2, Milestone (r)=2, completed=100.0%): {TERMINATED: 1} <br>Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.29 GiB heap, 0.0/3.64 GiB objects (0.0/1.0 accelerator_type:T4)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc           </th><th style="text-align: right;">  conv_block1_filters</th><th style="text-align: right;">  dropout_rate</th><th style="text-align: right;">  fc1_units</th><th>fc_layer_type  </th><th style="text-align: right;">  lr</th><th>pool_type  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  val_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_3bfb405e</td><td>TERMINATED</td><td>172.28.0.2:673</td><td style="text-align: right;">                    8</td><td style="text-align: right;">           0.3</td><td style="text-align: right;">         16</td><td>dense          </td><td style="text-align: right;">0.01</td><td>average    </td><td style="text-align: right;">     1</td><td style="text-align: right;">         197.908</td><td style="text-align: right;">0.778405</td><td style="text-align: right;">  0.706828</td><td style="text-align: right;">  0.530864</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (train_mnist pid=673) 2022-11-17 15:41:20.632498: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (train_mnist pid=673) Model: "model"
# (train_mnist pid=673) _________________________________________________________________
# (train_mnist pid=673)  Layer (type)                Output Shape              Param #
# (train_mnist pid=673) =================================================================
# (train_mnist pid=673)  input_1 (InputLayer)        [(None, 43893, 1)]        0
# (train_mnist pid=673)
# (train_mnist pid=673)  conv1d (Conv1D)             (None, 43886, 8)          72
# (train_mnist pid=673)
# (train_mnist pid=673)  batch_normalization (BatchN  (None, 43886, 8)         32
# (train_mnist pid=673)  ormalization)
# (train_mnist pid=673)
# (train_mnist pid=673)  activation (Activation)     (None, 43886, 8)          0
# (train_mnist pid=673)
# (train_mnist pid=673)  global_average_pooling1d (G  (None, 8)                0
# (train_mnist pid=673)  lobalAveragePooling1D)
# (train_mnist pid=673)
# (train_mnist pid=673)  dense (Dense)               (None, 16)                144
# (train_mnist pid=673)
# (train_mnist pid=673)  dropout (Dropout)           (None, 16)                0
# (train_mnist pid=673)
# (train_mnist pid=673)  batch_normalization_1 (Batc  (None, 16)               64
# (train_mnist pid=673)  hNormalization)
# (train_mnist pid=673)
# (train_mnist pid=673)  activation_1 (Activation)   (None, 16)                0
# (train_mnist pid=673)
# (train_mnist pid=673)  dense_1 (Dense)             (None, 2)                 34
# (train_mnist pid=673)
# (train_mnist pid=673)  dropout_1 (Dropout)         (None, 2)                 0
# (train_mnist pid=673)
# (train_mnist pid=673)  batch_normalization_2 (Batc  (None, 2)                8
# (train_mnist pid=673)  hNormalization)
# (train_mnist pid=673)
# (train_mnist pid=673)  dense_2 (Dense)             (None, 1)                 3
# (train_mnist pid=673)
# (train_mnist pid=673) =================================================================
# (train_mnist pid=673) Total params: 357
# (train_mnist pid=673) Trainable params: 305
# (train_mnist pid=673) Non-trainable params: 52
# (train_mnist pid=673) _________________________________________________________________
# (train_mnist pid=673) None
# (train_mnist pid=673) Total number of layers: 13
# (train_mnist pid=673) Epoch 1/100
# (train_mnist pid=673) WARNING:tensorflow:AutoGraph could not transform <function f1_m at 0x7efcb86ed050> and will run it as-is.
# (train_mnist pid=673) Cause: Unable to locate the source code of <function f1_m at 0x7efcb86ed050>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# (train_mnist pid=673) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (train_mnist pid=673) WARNING:tensorflow:AutoGraph could not transform <function f1_m at 0x7efcb86ed050> and will run it as-is.
# (train_mnist pid=673) Cause: Unable to locate the source code of <function f1_m at 0x7efcb86ed050>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# (train_mnist pid=673) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (train_mnist pid=673) WARNING:tensorflow:AutoGraph could not transform <function precision_m at 0x7efcb86f3830> and will run it as-is.
# (train_mnist pid=673) Cause: Unable to locate the source code of <function precision_m at 0x7efcb86f3830>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# (train_mnist pid=673) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (train_mnist pid=673) WARNING:tensorflow:AutoGraph could not transform <function precision_m at 0x7efcb86f3830> and will run it as-is.
# (train_mnist pid=673) Cause: Unable to locate the source code of <function precision_m at 0x7efcb86f3830>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# (train_mnist pid=673) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (train_mnist pid=673) WARNING:tensorflow:AutoGraph could not transform <function recall_m at 0x7efc5fee37a0> and will run it as-is.
# (train_mnist pid=673) Cause: Unable to locate the source code of <function recall_m at 0x7efc5fee37a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# (train_mnist pid=673) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (train_mnist pid=673) WARNING:tensorflow:AutoGraph could not transform <function recall_m at 0x7efc5fee37a0> and will run it as-is.
# (train_mnist pid=673) Cause: Unable to locate the source code of <function recall_m at 0x7efc5fee37a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# (train_mnist pid=673) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/6 [====>.........................] - ETA: 11s - loss: 0.7089 - accuracy: 0.5625 - f1_m: 0.5882 - precision_m: 0.5882 - recall_m: 0.5882
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7290 - accuracy: 0.5625 - f1_m: 0.5882 - precision_m: 0.5573 - recall_m: 0.6275
# 3/6 [==============>...............] - ETA: 0s - loss: 0.8007 - accuracy: 0.5208 - f1_m: 0.5380 - precision_m: 0.5271 - recall_m: 0.5556
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7832 - accuracy: 0.5312 - f1_m: 0.5368 - precision_m: 0.5286 - recall_m: 0.5500
# 5/6 [========================>.....] - ETA: 0s - loss: 0.7706 - accuracy: 0.5375 - f1_m: 0.5595 - precision_m: 0.5598 - recall_m: 0.5638
# 6/6 [==============================] - 4s 346ms/step - loss: 0.7784 - accuracy: 0.5309 - f1_m: 0.4662 - precision_m: 0.4665 - recall_m: 0.4698 - val_loss: 0.7068 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 2/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7947 - accuracy: 0.5312 - f1_m: 0.5714 - precision_m: 0.5882 - recall_m: 0.5556
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7131 - accuracy: 0.5938 - f1_m: 0.6516 - precision_m: 0.6066 - recall_m: 0.7190
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7528 - accuracy: 0.5417 - f1_m: 0.6010 - precision_m: 0.5711 - recall_m: 0.6460
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7468 - accuracy: 0.5312 - f1_m: 0.5897 - precision_m: 0.5474 - recall_m: 0.6511
# 5/6 [========================>.....] - ETA: 0s - loss: 0.7367 - accuracy: 0.5250 - f1_m: 0.5776 - precision_m: 0.5379 - recall_m: 0.6334
# 6/6 [==============================] - 2s 275ms/step - loss: 0.7372 - accuracy: 0.5247 - f1_m: 0.5925 - precision_m: 0.6149 - recall_m: 0.6112 - val_loss: 0.7021 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 3/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.5724 - accuracy: 0.7812 - f1_m: 0.8205 - precision_m: 0.8000 - recall_m: 0.8421
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6691 - accuracy: 0.6250 - f1_m: 0.7126 - precision_m: 0.7250 - recall_m: 0.7037
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7159 - accuracy: 0.5729 - f1_m: 0.6367 - precision_m: 0.6315 - recall_m: 0.6469
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7002 - accuracy: 0.5703 - f1_m: 0.6181 - precision_m: 0.5986 - recall_m: 0.6459
# 6/6 [==============================] - 2s 271ms/step - loss: 0.6969 - accuracy: 0.5864 - f1_m: 0.6866 - precision_m: 0.6574 - recall_m: 0.7282 - val_loss: 0.7015 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 4/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7091 - accuracy: 0.5312 - f1_m: 0.5946 - precision_m: 0.4583 - recall_m: 0.8462
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6915 - accuracy: 0.5938 - f1_m: 0.6632 - precision_m: 0.5701 - recall_m: 0.8178
# 3/6 [==============>...............] - ETA: 1s - loss: 0.7331 - accuracy: 0.5729 - f1_m: 0.6472 - precision_m: 0.5705 - recall_m: 0.7674
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7045 - accuracy: 0.5859 - f1_m: 0.6640 - precision_m: 0.5983 - recall_m: 0.7631
# 5/6 [========================>.....] - ETA: 0s - loss: 0.7044 - accuracy: 0.5813 - f1_m: 0.6534 - precision_m: 0.5787 - recall_m: 0.7676
# 6/6 [==============================] - 2s 288ms/step - loss: 0.7044 - accuracy: 0.5802 - f1_m: 0.6556 - precision_m: 0.6489 - recall_m: 0.7230 - val_loss: 0.6957 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 5/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6563 - accuracy: 0.4688 - f1_m: 0.5143 - precision_m: 0.4091 - recall_m: 0.6923
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7066 - accuracy: 0.5156 - f1_m: 0.5905 - precision_m: 0.5227 - recall_m: 0.6962
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7166 - accuracy: 0.5104 - f1_m: 0.5866 - precision_m: 0.5013 - recall_m: 0.7260
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7046 - accuracy: 0.5156 - f1_m: 0.5938 - precision_m: 0.5188 - recall_m: 0.7112
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6943 - accuracy: 0.5250 - f1_m: 0.6051 - precision_m: 0.5389 - recall_m: 0.7058
# 6/6 [==============================] - 2s 284ms/step - loss: 0.6940 - accuracy: 0.5247 - f1_m: 0.6153 - precision_m: 0.6157 - recall_m: 0.6715 - val_loss: 0.6945 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 6/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7062 - accuracy: 0.5000 - f1_m: 0.5789 - precision_m: 0.4583 - recall_m: 0.7857
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7010 - accuracy: 0.5312 - f1_m: 0.6228 - precision_m: 0.5208 - recall_m: 0.7817
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6941 - accuracy: 0.5625 - f1_m: 0.6616 - precision_m: 0.6048 - recall_m: 0.7573
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6663 - accuracy: 0.5703 - f1_m: 0.6533 - precision_m: 0.5732 - recall_m: 0.7971
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6855 - accuracy: 0.5500 - f1_m: 0.6355 - precision_m: 0.5585 - recall_m: 0.7671
# 6/6 [==============================] - 2s 273ms/step - loss: 0.6898 - accuracy: 0.5432 - f1_m: 0.5296 - precision_m: 0.4654 - recall_m: 0.6393 - val_loss: 0.6942 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 7/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6387 - accuracy: 0.5312 - f1_m: 0.5946 - precision_m: 0.5238 - recall_m: 0.6875
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7075 - accuracy: 0.5312 - f1_m: 0.5946 - precision_m: 0.5119 - recall_m: 0.7104
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6991 - accuracy: 0.5625 - f1_m: 0.6186 - precision_m: 0.5635 - recall_m: 0.6958
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6893 - accuracy: 0.5547 - f1_m: 0.5930 - precision_m: 0.5655 - recall_m: 0.6395
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6832 - accuracy: 0.5625 - f1_m: 0.5905 - precision_m: 0.5908 - recall_m: 0.6116
# 6/6 [==============================] - 2s 277ms/step - loss: 0.6830 - accuracy: 0.5617 - f1_m: 0.6032 - precision_m: 0.6590 - recall_m: 0.5930 - val_loss: 0.6927 - val_accuracy: 0.5789 - val_f1_m: 0.3333 - val_precision_m: 1.0000 - val_recall_m: 0.2000
# (train_mnist pid=673) Epoch 8/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7013 - accuracy: 0.5000 - f1_m: 0.6000 - precision_m: 0.5000 - recall_m: 0.7500
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7352 - accuracy: 0.4375 - f1_m: 0.5368 - precision_m: 0.4457 - recall_m: 0.6750
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7172 - accuracy: 0.4792 - f1_m: 0.5684 - precision_m: 0.5076 - recall_m: 0.6605
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6987 - accuracy: 0.5312 - f1_m: 0.6220 - precision_m: 0.5682 - recall_m: 0.6999
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6989 - accuracy: 0.5250 - f1_m: 0.6087 - precision_m: 0.5415 - recall_m: 0.7138
# 6/6 [==============================] - 2s 268ms/step - loss: 0.6955 - accuracy: 0.5309 - f1_m: 0.6739 - precision_m: 0.6179 - recall_m: 0.7615 - val_loss: 0.6913 - val_accuracy: 0.5263 - val_f1_m: 0.5263 - val_precision_m: 0.5556 - val_recall_m: 0.5000
# (train_mnist pid=673) Epoch 9/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6310 - accuracy: 0.6562 - f1_m: 0.7317 - precision_m: 0.6000 - recall_m: 0.9375
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6612 - accuracy: 0.5938 - f1_m: 0.6735 - precision_m: 0.5609 - recall_m: 0.8438
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6854 - accuracy: 0.5625 - f1_m: 0.6420 - precision_m: 0.5572 - recall_m: 0.7662
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6767 - accuracy: 0.5625 - f1_m: 0.6482 - precision_m: 0.5579 - recall_m: 0.7805
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6628 - accuracy: 0.5938 - f1_m: 0.6746 - precision_m: 0.5797 - recall_m: 0.8127
# 6/6 [==============================] - 2s 270ms/step - loss: 0.6628 - accuracy: 0.5926 - f1_m: 0.6733 - precision_m: 0.6497 - recall_m: 0.7606 - val_loss: 0.6899 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 10/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7143 - accuracy: 0.5625 - f1_m: 0.6667 - precision_m: 0.5600 - recall_m: 0.8235
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7219 - accuracy: 0.5312 - f1_m: 0.6228 - precision_m: 0.5419 - recall_m: 0.7353
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6789 - accuracy: 0.5729 - f1_m: 0.6591 - precision_m: 0.5994 - recall_m: 0.7402
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7123 - accuracy: 0.5156 - f1_m: 0.6097 - precision_m: 0.5395 - recall_m: 0.7159
# 5/6 [========================>.....] - ETA: 0s - loss: 0.7054 - accuracy: 0.5375 - f1_m: 0.6278 - precision_m: 0.5483 - recall_m: 0.7477
# 6/6 [==============================] - 2s 274ms/step - loss: 0.7046 - accuracy: 0.5370 - f1_m: 0.6343 - precision_m: 0.6236 - recall_m: 0.7064 - val_loss: 0.6932 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 11/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.8186 - accuracy: 0.4688 - f1_m: 0.5143 - precision_m: 0.3913 - recall_m: 0.7500
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7536 - accuracy: 0.5312 - f1_m: 0.6060 - precision_m: 0.4957 - recall_m: 0.7917
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7428 - accuracy: 0.5417 - f1_m: 0.6207 - precision_m: 0.5110 - recall_m: 0.7986
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7052 - accuracy: 0.5703 - f1_m: 0.6570 - precision_m: 0.5632 - recall_m: 0.8035
# 5/6 [========================>.....] - ETA: 0s - loss: 0.7158 - accuracy: 0.5312 - f1_m: 0.6256 - precision_m: 0.5376 - recall_m: 0.7605
# 6/6 [==============================] - 2s 270ms/step - loss: 0.7172 - accuracy: 0.5247 - f1_m: 0.5213 - precision_m: 0.4480 - recall_m: 0.6337 - val_loss: 0.6960 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 12/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6798 - accuracy: 0.6250 - f1_m: 0.6471 - precision_m: 0.6471 - recall_m: 0.6471
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6798 - accuracy: 0.5938 - f1_m: 0.6714 - precision_m: 0.6714 - recall_m: 0.6714
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7084 - accuracy: 0.5417 - f1_m: 0.6044 - precision_m: 0.5809 - recall_m: 0.6380
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7284 - accuracy: 0.5078 - f1_m: 0.5875 - precision_m: 0.5414 - recall_m: 0.6619
# 5/6 [========================>.....] - ETA: 0s - loss: 0.7225 - accuracy: 0.5125 - f1_m: 0.5889 - precision_m: 0.5332 - recall_m: 0.6762
# 6/6 [==============================] - 2s 270ms/step - loss: 0.7211 - accuracy: 0.5123 - f1_m: 0.6019 - precision_m: 0.6110 - recall_m: 0.6468 - val_loss: 0.6961 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 13/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6541 - accuracy: 0.6562 - f1_m: 0.7442 - precision_m: 0.7273 - recall_m: 0.7619
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7034 - accuracy: 0.5781 - f1_m: 0.6368 - precision_m: 0.5682 - recall_m: 0.7560
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6983 - accuracy: 0.5521 - f1_m: 0.6309 - precision_m: 0.5851 - recall_m: 0.7103
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6806 - accuracy: 0.5781 - f1_m: 0.6526 - precision_m: 0.6139 - recall_m: 0.7169
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6913 - accuracy: 0.5625 - f1_m: 0.6379 - precision_m: 0.5791 - recall_m: 0.7428
# 6/6 [==============================] - 2s 279ms/step - loss: 0.6932 - accuracy: 0.5617 - f1_m: 0.5316 - precision_m: 0.4826 - recall_m: 0.6190 - val_loss: 0.6930 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 14/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7274 - accuracy: 0.6250 - f1_m: 0.7273 - precision_m: 0.6154 - recall_m: 0.8889
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6884 - accuracy: 0.6406 - f1_m: 0.7226 - precision_m: 0.6259 - recall_m: 0.8562
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6833 - accuracy: 0.6562 - f1_m: 0.7170 - precision_m: 0.6395 - recall_m: 0.8208
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6703 - accuracy: 0.6641 - f1_m: 0.7183 - precision_m: 0.6344 - recall_m: 0.8323
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6765 - accuracy: 0.6125 - f1_m: 0.6772 - precision_m: 0.6027 - recall_m: 0.7769
# 6/6 [==============================] - 2s 268ms/step - loss: 0.6758 - accuracy: 0.6111 - f1_m: 0.6755 - precision_m: 0.6689 - recall_m: 0.7308 - val_loss: 0.6922 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 15/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6811 - accuracy: 0.6250 - f1_m: 0.6667 - precision_m: 0.6667 - recall_m: 0.6667
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6707 - accuracy: 0.5469 - f1_m: 0.6154 - precision_m: 0.5833 - recall_m: 0.6569
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6804 - accuracy: 0.5938 - f1_m: 0.6642 - precision_m: 0.6111 - recall_m: 0.7342
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6901 - accuracy: 0.5703 - f1_m: 0.6305 - precision_m: 0.5768 - recall_m: 0.7007
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6900 - accuracy: 0.5750 - f1_m: 0.6410 - precision_m: 0.5734 - recall_m: 0.7355
# 6/6 [==============================] - 2s 280ms/step - loss: 0.6890 - accuracy: 0.5741 - f1_m: 0.6453 - precision_m: 0.6445 - recall_m: 0.6963 - val_loss: 0.6918 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 16/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7388 - accuracy: 0.4062 - f1_m: 0.4865 - precision_m: 0.3600 - recall_m: 0.7500
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7181 - accuracy: 0.4531 - f1_m: 0.5528 - precision_m: 0.4300 - recall_m: 0.7812
# 3/6 [==============>...............] - ETA: 0s - loss: 0.7134 - accuracy: 0.4583 - f1_m: 0.5636 - precision_m: 0.4295 - recall_m: 0.8285
# 4/6 [===================>..........] - ETA: 0s - loss: 0.7073 - accuracy: 0.4375 - f1_m: 0.5477 - precision_m: 0.4537 - recall_m: 0.7404
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6888 - accuracy: 0.5000 - f1_m: 0.6062 - precision_m: 0.5185 - recall_m: 0.7750
# 6/6 [==============================] - 2s 269ms/step - loss: 0.6867 - accuracy: 0.5062 - f1_m: 0.6718 - precision_m: 0.5988 - recall_m: 0.8125 - val_loss: 0.6909 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 17/100
# 1/6 [====>.........................] - ETA: 3s - loss: 0.7393 - accuracy: 0.4375 - f1_m: 0.5263 - precision_m: 0.4167 - recall_m: 0.7143
# 2/6 [=========>....................] - ETA: 2s - loss: 0.6952 - accuracy: 0.5312 - f1_m: 0.6268 - precision_m: 0.5283 - recall_m: 0.7782
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6888 - accuracy: 0.5000 - f1_m: 0.5933 - precision_m: 0.4971 - recall_m: 0.7410
# 4/6 [===================>..........] - ETA: 1s - loss: 0.6779 - accuracy: 0.5469 - f1_m: 0.6325 - precision_m: 0.5433 - recall_m: 0.7641
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6686 - accuracy: 0.5938 - f1_m: 0.6749 - precision_m: 0.5867 - recall_m: 0.8013
# 6/6 [==============================] - 3s 395ms/step - loss: 0.6705 - accuracy: 0.5926 - f1_m: 0.5624 - precision_m: 0.4889 - recall_m: 0.6677 - val_loss: 0.6905 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 18/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6978 - accuracy: 0.5625 - f1_m: 0.6500 - precision_m: 0.5909 - recall_m: 0.7222
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6816 - accuracy: 0.5938 - f1_m: 0.6485 - precision_m: 0.6190 - recall_m: 0.6846
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6626 - accuracy: 0.5833 - f1_m: 0.6490 - precision_m: 0.6190 - recall_m: 0.6845
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6539 - accuracy: 0.6172 - f1_m: 0.6686 - precision_m: 0.6309 - recall_m: 0.7134
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6553 - accuracy: 0.6313 - f1_m: 0.6793 - precision_m: 0.6416 - recall_m: 0.7236
# 6/6 [==============================] - 2s 276ms/step - loss: 0.6571 - accuracy: 0.6296 - f1_m: 0.5661 - precision_m: 0.5346 - recall_m: 0.6030 - val_loss: 0.6902 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=673) Epoch 19/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7496 - accuracy: 0.4375 - f1_m: 0.4000 - precision_m: 0.4286 - recall_m: 0.3750
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7065 - accuracy: 0.5625 - f1_m: 0.5333 - precision_m: 0.5268 - recall_m: 0.5446
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6846 - accuracy: 0.5729 - f1_m: 0.5651 - precision_m: 0.5804 - recall_m: 0.5561
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6831 - accuracy: 0.5781 - f1_m: 0.5860 - precision_m: 0.6019 - recall_m: 0.5750
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6797 - accuracy: 0.6000 - f1_m: 0.6188 - precision_m: 0.6179 - recall_m: 0.6266
# 6/6 [==============================] - 2s 265ms/step - loss: 0.6811 - accuracy: 0.5988 - f1_m: 0.5156 - precision_m: 0.5149 - recall_m: 0.5222 - val_loss: 0.6922 - val_accuracy: 0.5789 - val_f1_m: 0.3333 - val_precision_m: 1.0000 - val_recall_m: 0.2000
# (train_mnist pid=673) Epoch 20/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7043 - accuracy: 0.5938 - f1_m: 0.5806 - precision_m: 0.6000 - recall_m: 0.5625
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6914 - accuracy: 0.6094 - f1_m: 0.6237 - precision_m: 0.6750 - recall_m: 0.5813
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6879 - accuracy: 0.5833 - f1_m: 0.5767 - precision_m: 0.6056 - recall_m: 0.5542
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6802 - accuracy: 0.5781 - f1_m: 0.5731 - precision_m: 0.6149 - recall_m: 0.5406
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6949 - accuracy: 0.5375 - f1_m: 0.5335 - precision_m: 0.5719 - recall_m: 0.5031
# 6/6 [==============================] - 2s 264ms/step - loss: 0.6928 - accuracy: 0.5432 - f1_m: 0.6113 - precision_m: 0.6433 - recall_m: 0.5859 - val_loss: 0.6989 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 21/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6687 - accuracy: 0.5938 - f1_m: 0.6486 - precision_m: 0.5217 - recall_m: 0.8571
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6544 - accuracy: 0.6250 - f1_m: 0.6757 - precision_m: 0.5704 - recall_m: 0.8348
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6767 - accuracy: 0.6042 - f1_m: 0.6542 - precision_m: 0.5840 - recall_m: 0.7603
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6713 - accuracy: 0.6094 - f1_m: 0.6469 - precision_m: 0.5942 - recall_m: 0.7264
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6805 - accuracy: 0.5625 - f1_m: 0.6064 - precision_m: 0.5897 - recall_m: 0.6539
# 6/6 [==============================] - 2s 283ms/step - loss: 0.6817 - accuracy: 0.5617 - f1_m: 0.5053 - precision_m: 0.4914 - recall_m: 0.5449 - val_loss: 0.7000 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 22/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6631 - accuracy: 0.5312 - f1_m: 0.5161 - precision_m: 0.4000 - recall_m: 0.7273
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6350 - accuracy: 0.6250 - f1_m: 0.6295 - precision_m: 0.6643 - recall_m: 0.6732
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6631 - accuracy: 0.5625 - f1_m: 0.5387 - precision_m: 0.5944 - recall_m: 0.5468
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6697 - accuracy: 0.5625 - f1_m: 0.5290 - precision_m: 0.6049 - recall_m: 0.5131
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6681 - accuracy: 0.5750 - f1_m: 0.5482 - precision_m: 0.6268 - recall_m: 0.5216
# 6/6 [==============================] - 2s 273ms/step - loss: 0.6682 - accuracy: 0.5741 - f1_m: 0.5680 - precision_m: 0.6890 - recall_m: 0.5180 - val_loss: 0.6975 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 23/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6950 - accuracy: 0.4688 - f1_m: 0.5641 - precision_m: 0.6111 - recall_m: 0.5238
# 2/6 [=========>....................] - ETA: 1s - loss: 0.7044 - accuracy: 0.4844 - f1_m: 0.5598 - precision_m: 0.5328 - recall_m: 0.6190
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6805 - accuracy: 0.5312 - f1_m: 0.6013 - precision_m: 0.5522 - recall_m: 0.6835
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6803 - accuracy: 0.5234 - f1_m: 0.5833 - precision_m: 0.5391 - recall_m: 0.6533
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6714 - accuracy: 0.5437 - f1_m: 0.5961 - precision_m: 0.5607 - recall_m: 0.6520
# 6/6 [==============================] - 2s 275ms/step - loss: 0.6711 - accuracy: 0.5432 - f1_m: 0.6078 - precision_m: 0.6339 - recall_m: 0.6267 - val_loss: 0.6939 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 24/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6323 - accuracy: 0.5938 - f1_m: 0.6977 - precision_m: 0.7895 - recall_m: 0.6250
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6462 - accuracy: 0.5938 - f1_m: 0.6977 - precision_m: 0.6832 - recall_m: 0.7537
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6552 - accuracy: 0.5833 - f1_m: 0.6688 - precision_m: 0.6301 - recall_m: 0.7469
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6571 - accuracy: 0.5703 - f1_m: 0.6445 - precision_m: 0.6196 - recall_m: 0.6991
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6678 - accuracy: 0.5562 - f1_m: 0.6156 - precision_m: 0.5684 - recall_m: 0.7192
# 6/6 [==============================] - 2s 265ms/step - loss: 0.6675 - accuracy: 0.5556 - f1_m: 0.6241 - precision_m: 0.6403 - recall_m: 0.6827 - val_loss: 0.7164 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 25/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6698 - accuracy: 0.6562 - f1_m: 0.7442 - precision_m: 0.6957 - recall_m: 0.8000
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6677 - accuracy: 0.6562 - f1_m: 0.7379 - precision_m: 0.6603 - recall_m: 0.8412
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6660 - accuracy: 0.6458 - f1_m: 0.7200 - precision_m: 0.6286 - recall_m: 0.8497
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6863 - accuracy: 0.6094 - f1_m: 0.6948 - precision_m: 0.6015 - recall_m: 0.8284
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6829 - accuracy: 0.6062 - f1_m: 0.6924 - precision_m: 0.5978 - recall_m: 0.8275
# 6/6 [==============================] - 2s 267ms/step - loss: 0.6843 - accuracy: 0.6049 - f1_m: 0.5770 - precision_m: 0.4982 - recall_m: 0.6895 - val_loss: 0.7165 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 26/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6770 - accuracy: 0.5938 - f1_m: 0.7111 - precision_m: 0.6667 - recall_m: 0.7619
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6967 - accuracy: 0.5469 - f1_m: 0.6056 - precision_m: 0.5238 - recall_m: 0.7446
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6965 - accuracy: 0.5312 - f1_m: 0.6037 - precision_m: 0.5159 - recall_m: 0.7464
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6845 - accuracy: 0.5625 - f1_m: 0.6388 - precision_m: 0.5608 - recall_m: 0.7598
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6777 - accuracy: 0.5750 - f1_m: 0.6539 - precision_m: 0.5640 - recall_m: 0.7953
# 6/6 [==============================] - 2s 263ms/step - loss: 0.6771 - accuracy: 0.5802 - f1_m: 0.7116 - precision_m: 0.6367 - recall_m: 0.8294 - val_loss: 0.7050 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 27/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6719 - accuracy: 0.6250 - f1_m: 0.6667 - precision_m: 0.5217 - recall_m: 0.9231
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6652 - accuracy: 0.6562 - f1_m: 0.7197 - precision_m: 0.6472 - recall_m: 0.8479
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6544 - accuracy: 0.6458 - f1_m: 0.7131 - precision_m: 0.6110 - recall_m: 0.8986
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6608 - accuracy: 0.6172 - f1_m: 0.6887 - precision_m: 0.6011 - recall_m: 0.8406
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6654 - accuracy: 0.5875 - f1_m: 0.6638 - precision_m: 0.5856 - recall_m: 0.7947
# 6/6 [==============================] - 2s 263ms/step - loss: 0.6635 - accuracy: 0.5926 - f1_m: 0.7198 - precision_m: 0.6547 - recall_m: 0.8289 - val_loss: 0.7180 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 28/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7045 - accuracy: 0.5000 - f1_m: 0.5294 - precision_m: 0.3913 - recall_m: 0.8182
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6909 - accuracy: 0.5625 - f1_m: 0.6343 - precision_m: 0.5357 - recall_m: 0.8139
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6876 - accuracy: 0.5729 - f1_m: 0.6505 - precision_m: 0.5600 - recall_m: 0.8018
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6871 - accuracy: 0.5938 - f1_m: 0.6708 - precision_m: 0.5700 - recall_m: 0.8357
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6688 - accuracy: 0.6187 - f1_m: 0.6948 - precision_m: 0.5977 - recall_m: 0.8475
# 6/6 [==============================] - 2s 282ms/step - loss: 0.6723 - accuracy: 0.6111 - f1_m: 0.5790 - precision_m: 0.4981 - recall_m: 0.7063 - val_loss: 0.7021 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 29/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6162 - accuracy: 0.7188 - f1_m: 0.7805 - precision_m: 0.6957 - recall_m: 0.8889
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6566 - accuracy: 0.6406 - f1_m: 0.7152 - precision_m: 0.6078 - recall_m: 0.8778
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6736 - accuracy: 0.6042 - f1_m: 0.6939 - precision_m: 0.6173 - recall_m: 0.8074
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6621 - accuracy: 0.6250 - f1_m: 0.7109 - precision_m: 0.6369 - recall_m: 0.8161
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6697 - accuracy: 0.5938 - f1_m: 0.6657 - precision_m: 0.5857 - recall_m: 0.7862
# 6/6 [==============================] - 2s 301ms/step - loss: 0.6721 - accuracy: 0.5864 - f1_m: 0.5547 - precision_m: 0.4881 - recall_m: 0.6552 - val_loss: 0.6999 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 30/100
# 1/6 [====>.........................] - ETA: 2s - loss: 0.6797 - accuracy: 0.5000 - f1_m: 0.6364 - precision_m: 0.5600 - recall_m: 0.7368
# 2/6 [=========>....................] - ETA: 2s - loss: 0.6772 - accuracy: 0.5156 - f1_m: 0.6353 - precision_m: 0.5300 - recall_m: 0.8018
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6884 - accuracy: 0.5208 - f1_m: 0.6349 - precision_m: 0.5267 - recall_m: 0.8053
# 4/6 [===================>..........] - ETA: 1s - loss: 0.6811 - accuracy: 0.5703 - f1_m: 0.6619 - precision_m: 0.5575 - recall_m: 0.8207
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6692 - accuracy: 0.5938 - f1_m: 0.6795 - precision_m: 0.5889 - recall_m: 0.8144
# 6/6 [==============================] - 3s 470ms/step - loss: 0.6690 - accuracy: 0.5926 - f1_m: 0.6774 - precision_m: 0.6574 - recall_m: 0.7620 - val_loss: 0.6938 - val_accuracy: 0.5263 - val_f1_m: 0.1818 - val_precision_m: 1.0000 - val_recall_m: 0.1000
# (train_mnist pid=673) Epoch 31/100
# 1/6 [====>.........................] - ETA: 2s - loss: 0.6505 - accuracy: 0.5938 - f1_m: 0.6667 - precision_m: 0.5652 - recall_m: 0.8125
# 2/6 [=========>....................] - ETA: 2s - loss: 0.6868 - accuracy: 0.5625 - f1_m: 0.6306 - precision_m: 0.5326 - recall_m: 0.7729
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6680 - accuracy: 0.5833 - f1_m: 0.6538 - precision_m: 0.5495 - recall_m: 0.8069
# 4/6 [===================>..........] - ETA: 1s - loss: 0.6664 - accuracy: 0.5938 - f1_m: 0.6614 - precision_m: 0.5746 - recall_m: 0.7858
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6759 - accuracy: 0.5688 - f1_m: 0.6462 - precision_m: 0.5688 - recall_m: 0.7549
# 6/6 [==============================] - 3s 439ms/step - loss: 0.6753 - accuracy: 0.5679 - f1_m: 0.6496 - precision_m: 0.6407 - recall_m: 0.7124 - val_loss: 0.6967 - val_accuracy: 0.5263 - val_f1_m: 0.1818 - val_precision_m: 1.0000 - val_recall_m: 0.1000
# (train_mnist pid=673) Epoch 32/100
# 1/6 [====>.........................] - ETA: 2s - loss: 0.6567 - accuracy: 0.6562 - f1_m: 0.7317 - precision_m: 0.6000 - recall_m: 0.9375
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6576 - accuracy: 0.6719 - f1_m: 0.7468 - precision_m: 0.6636 - recall_m: 0.8687
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6778 - accuracy: 0.5938 - f1_m: 0.6645 - precision_m: 0.5674 - recall_m: 0.8292
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6743 - accuracy: 0.5859 - f1_m: 0.6651 - precision_m: 0.5602 - recall_m: 0.8406
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6709 - accuracy: 0.6062 - f1_m: 0.6886 - precision_m: 0.5921 - recall_m: 0.8439
# 6/6 [==============================] - 2s 268ms/step - loss: 0.6689 - accuracy: 0.6111 - f1_m: 0.7405 - precision_m: 0.6601 - recall_m: 0.8699 - val_loss: 0.6943 - val_accuracy: 0.5789 - val_f1_m: 0.3333 - val_precision_m: 1.0000 - val_recall_m: 0.2000
# (train_mnist pid=673) Epoch 33/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6674 - accuracy: 0.7188 - f1_m: 0.8000 - precision_m: 0.6923 - recall_m: 0.9474
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6917 - accuracy: 0.5938 - f1_m: 0.6821 - precision_m: 0.5753 - recall_m: 0.8404
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6779 - accuracy: 0.5938 - f1_m: 0.6917 - precision_m: 0.6058 - recall_m: 0.8142
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6790 - accuracy: 0.5859 - f1_m: 0.6813 - precision_m: 0.5843 - recall_m: 0.8273
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6806 - accuracy: 0.5875 - f1_m: 0.6784 - precision_m: 0.5758 - recall_m: 0.8352
# 6/6 [==============================] - 2s 278ms/step - loss: 0.6783 - accuracy: 0.5926 - f1_m: 0.7320 - precision_m: 0.6465 - recall_m: 0.8627 - val_loss: 0.7318 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 34/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6776 - accuracy: 0.6250 - f1_m: 0.7143 - precision_m: 0.6818 - recall_m: 0.7500
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6589 - accuracy: 0.5938 - f1_m: 0.6821 - precision_m: 0.5909 - recall_m: 0.8393
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6592 - accuracy: 0.5938 - f1_m: 0.6873 - precision_m: 0.5862 - recall_m: 0.8536
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6629 - accuracy: 0.5781 - f1_m: 0.6740 - precision_m: 0.5697 - recall_m: 0.8434
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6614 - accuracy: 0.5750 - f1_m: 0.6692 - precision_m: 0.5688 - recall_m: 0.8276
# 6/6 [==============================] - 3s 438ms/step - loss: 0.6612 - accuracy: 0.5741 - f1_m: 0.6688 - precision_m: 0.6407 - recall_m: 0.7730 - val_loss: 0.7670 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 35/100
# 1/6 [====>.........................] - ETA: 2s - loss: 0.6467 - accuracy: 0.6250 - f1_m: 0.6842 - precision_m: 0.5417 - recall_m: 0.9286
# 2/6 [=========>....................] - ETA: 2s - loss: 0.6267 - accuracy: 0.6875 - f1_m: 0.7469 - precision_m: 0.6250 - recall_m: 0.9365
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6328 - accuracy: 0.6562 - f1_m: 0.7256 - precision_m: 0.6196 - recall_m: 0.8836
# 4/6 [===================>..........] - ETA: 1s - loss: 0.6315 - accuracy: 0.6406 - f1_m: 0.7108 - precision_m: 0.6194 - recall_m: 0.8433
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6375 - accuracy: 0.6250 - f1_m: 0.7020 - precision_m: 0.6122 - recall_m: 0.8302
# 6/6 [==============================] - 3s 471ms/step - loss: 0.6401 - accuracy: 0.6235 - f1_m: 0.5850 - precision_m: 0.5102 - recall_m: 0.6918 - val_loss: 0.7691 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 36/100
# 1/6 [====>.........................] - ETA: 2s - loss: 0.6548 - accuracy: 0.6562 - f1_m: 0.7442 - precision_m: 0.6667 - recall_m: 0.8421
# 2/6 [=========>....................] - ETA: 2s - loss: 0.6561 - accuracy: 0.6094 - f1_m: 0.6971 - precision_m: 0.6429 - recall_m: 0.7632
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6413 - accuracy: 0.6354 - f1_m: 0.7103 - precision_m: 0.6508 - recall_m: 0.7833
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6479 - accuracy: 0.6250 - f1_m: 0.6899 - precision_m: 0.6190 - recall_m: 0.7839
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6608 - accuracy: 0.6000 - f1_m: 0.6719 - precision_m: 0.5952 - recall_m: 0.7771
# 6/6 [==============================] - 2s 387ms/step - loss: 0.6642 - accuracy: 0.5926 - f1_m: 0.5599 - precision_m: 0.4960 - recall_m: 0.6476 - val_loss: 0.7136 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 37/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6518 - accuracy: 0.6250 - f1_m: 0.7000 - precision_m: 0.6087 - recall_m: 0.8235
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6429 - accuracy: 0.6250 - f1_m: 0.7000 - precision_m: 0.6377 - recall_m: 0.7802
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6532 - accuracy: 0.6146 - f1_m: 0.6829 - precision_m: 0.6069 - recall_m: 0.7868
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6696 - accuracy: 0.5781 - f1_m: 0.6473 - precision_m: 0.5639 - recall_m: 0.7687
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6612 - accuracy: 0.6062 - f1_m: 0.6778 - precision_m: 0.6011 - recall_m: 0.7864
# 6/6 [==============================] - 2s 276ms/step - loss: 0.6629 - accuracy: 0.6049 - f1_m: 0.5649 - precision_m: 0.5009 - recall_m: 0.6553 - val_loss: 0.7311 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=673) Epoch 38/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6207 - accuracy: 0.5625 - f1_m: 0.6316 - precision_m: 0.5455 - recall_m: 0.7500
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6535 - accuracy: 0.5625 - f1_m: 0.6316 - precision_m: 0.5455 - recall_m: 0.7500
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6715 - accuracy: 0.5729 - f1_m: 0.6433 - precision_m: 0.5700 - recall_m: 0.7407
# ...
# (train_mnist pid=11657) Epoch 87/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.5842 - accuracy: 0.7188 - f1_m: 0.7907 - precision_m: 0.8095 - recall_m: 0.7727
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6109 - accuracy: 0.6406 - f1_m: 0.6895 - precision_m: 0.6320 - recall_m: 0.8030
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6219 - accuracy: 0.6146 - f1_m: 0.6763 - precision_m: 0.6380 - recall_m: 0.7520
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6467 - accuracy: 0.6094 - f1_m: 0.6739 - precision_m: 0.6262 - recall_m: 0.7552
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6746 - accuracy: 0.5750 - f1_m: 0.6444 - precision_m: 0.5880 - recall_m: 0.7375
# 6/6 [==============================] - 2s 281ms/step - loss: 0.6757 - accuracy: 0.5679 - f1_m: 0.5370 - precision_m: 0.4900 - recall_m: 0.6146 - val_loss: 0.7195 - val_accuracy: 0.5263 - val_f1_m: 0.3077 - val_precision_m: 0.6667 - val_recall_m: 0.2000
# (train_mnist pid=11657) Epoch 88/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6365 - accuracy: 0.6562 - f1_m: 0.6857 - precision_m: 0.5714 - recall_m: 0.8571
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6680 - accuracy: 0.6094 - f1_m: 0.6838 - precision_m: 0.6118 - recall_m: 0.7857
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6547 - accuracy: 0.6146 - f1_m: 0.6839 - precision_m: 0.6245 - recall_m: 0.7646
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6481 - accuracy: 0.6250 - f1_m: 0.6844 - precision_m: 0.6184 - recall_m: 0.7734
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6610 - accuracy: 0.5938 - f1_m: 0.6556 - precision_m: 0.6000 - recall_m: 0.7298
# 6/6 [==============================] - 2s 282ms/step - loss: 0.6620 - accuracy: 0.5926 - f1_m: 0.5463 - precision_m: 0.5000 - recall_m: 0.6082 - val_loss: 0.8249 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=11657) Epoch 89/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6636 - accuracy: 0.5000 - f1_m: 0.5294 - precision_m: 0.4500 - recall_m: 0.6429
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6505 - accuracy: 0.5781 - f1_m: 0.6161 - precision_m: 0.5671 - recall_m: 0.6825
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6512 - accuracy: 0.6146 - f1_m: 0.6607 - precision_m: 0.6162 - recall_m: 0.7182
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6644 - accuracy: 0.5859 - f1_m: 0.6279 - precision_m: 0.5805 - recall_m: 0.6886
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6566 - accuracy: 0.5938 - f1_m: 0.6423 - precision_m: 0.5978 - recall_m: 0.6983
# 6/6 [==============================] - 2s 291ms/step - loss: 0.6541 - accuracy: 0.5988 - f1_m: 0.7019 - precision_m: 0.6648 - recall_m: 0.7486 - val_loss: 0.7784 - val_accuracy: 0.4737 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# (train_mnist pid=11657) Epoch 90/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6212 - accuracy: 0.6562 - f1_m: 0.7317 - precision_m: 0.6818 - recall_m: 0.7895
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6185 - accuracy: 0.7031 - f1_m: 0.7547 - precision_m: 0.7298 - recall_m: 0.7836
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6553 - accuracy: 0.6458 - f1_m: 0.7083 - precision_m: 0.6971 - recall_m: 0.7224
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6520 - accuracy: 0.6484 - f1_m: 0.7026 - precision_m: 0.6728 - recall_m: 0.7418
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6537 - accuracy: 0.6375 - f1_m: 0.6782 - precision_m: 0.6330 - recall_m: 0.7435
# 6/6 [==============================] - 2s 301ms/step - loss: 0.6544 - accuracy: 0.6358 - f1_m: 0.6763 - precision_m: 0.6941 - recall_m: 0.7029 - val_loss: 0.7410 - val_accuracy: 0.5789 - val_f1_m: 0.3333 - val_precision_m: 1.0000 - val_recall_m: 0.2000
# (train_mnist pid=11657) Epoch 91/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7010 - accuracy: 0.5625 - f1_m: 0.5882 - precision_m: 0.5556 - recall_m: 0.6250
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6711 - accuracy: 0.5781 - f1_m: 0.6356 - precision_m: 0.5821 - recall_m: 0.7014
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6553 - accuracy: 0.6354 - f1_m: 0.6830 - precision_m: 0.6337 - recall_m: 0.7421
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6709 - accuracy: 0.6016 - f1_m: 0.6372 - precision_m: 0.5805 - recall_m: 0.7104
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6672 - accuracy: 0.6125 - f1_m: 0.6561 - precision_m: 0.6073 - recall_m: 0.7183
# 6/6 [==============================] - 2s 279ms/step - loss: 0.6674 - accuracy: 0.6111 - f1_m: 0.6579 - precision_m: 0.6727 - recall_m: 0.6819 - val_loss: 0.7342 - val_accuracy: 0.5263 - val_f1_m: 0.3077 - val_precision_m: 0.6667 - val_recall_m: 0.2000
# (train_mnist pid=11657) Epoch 92/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6560 - accuracy: 0.5938 - f1_m: 0.6486 - precision_m: 0.5714 - recall_m: 0.7500
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6466 - accuracy: 0.6250 - f1_m: 0.6757 - precision_m: 0.6107 - recall_m: 0.7574
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6605 - accuracy: 0.5729 - f1_m: 0.6306 - precision_m: 0.5659 - recall_m: 0.7132
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6714 - accuracy: 0.5859 - f1_m: 0.6548 - precision_m: 0.5911 - recall_m: 0.7349
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6656 - accuracy: 0.5875 - f1_m: 0.6572 - precision_m: 0.5812 - recall_m: 0.7613
# 6/6 [==============================] - 2s 290ms/step - loss: 0.6651 - accuracy: 0.5926 - f1_m: 0.7143 - precision_m: 0.6510 - recall_m: 0.8011 - val_loss: 0.6971 - val_accuracy: 0.5263 - val_f1_m: 0.6667 - val_precision_m: 0.5294 - val_recall_m: 0.9000
# (train_mnist pid=11657) Epoch 93/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.5738 - accuracy: 0.8125 - f1_m: 0.8571 - precision_m: 0.8182 - recall_m: 0.9000
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6481 - accuracy: 0.6875 - f1_m: 0.7536 - precision_m: 0.6799 - recall_m: 0.8562
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6547 - accuracy: 0.6667 - f1_m: 0.7357 - precision_m: 0.6562 - recall_m: 0.8453
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6404 - accuracy: 0.6641 - f1_m: 0.7378 - precision_m: 0.6660 - recall_m: 0.8340
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6608 - accuracy: 0.6313 - f1_m: 0.7061 - precision_m: 0.6208 - recall_m: 0.8364
# 6/6 [==============================] - 2s 287ms/step - loss: 0.6624 - accuracy: 0.6296 - f1_m: 0.5884 - precision_m: 0.5174 - recall_m: 0.6970 - val_loss: 0.8024 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=11657) Epoch 94/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6142 - accuracy: 0.6562 - f1_m: 0.7027 - precision_m: 0.6190 - recall_m: 0.8125
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6534 - accuracy: 0.6250 - f1_m: 0.6928 - precision_m: 0.6429 - recall_m: 0.7563
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6479 - accuracy: 0.6354 - f1_m: 0.6904 - precision_m: 0.6391 - recall_m: 0.7542
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6637 - accuracy: 0.6250 - f1_m: 0.6800 - precision_m: 0.6222 - recall_m: 0.7531
# 6/6 [==============================] - 2s 269ms/step - loss: 0.6595 - accuracy: 0.6111 - f1_m: 0.6697 - precision_m: 0.6724 - recall_m: 0.7104 - val_loss: 0.7110 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=11657) Epoch 95/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.7009 - accuracy: 0.4688 - f1_m: 0.5405 - precision_m: 0.4762 - recall_m: 0.6250
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6823 - accuracy: 0.5312 - f1_m: 0.5946 - precision_m: 0.5381 - recall_m: 0.6654
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6634 - accuracy: 0.5833 - f1_m: 0.6504 - precision_m: 0.5906 - recall_m: 0.7243
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6807 - accuracy: 0.5469 - f1_m: 0.6054 - precision_m: 0.5430 - recall_m: 0.6861
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6692 - accuracy: 0.5625 - f1_m: 0.6243 - precision_m: 0.5744 - recall_m: 0.6889
# 6/6 [==============================] - 2s 276ms/step - loss: 0.6709 - accuracy: 0.5617 - f1_m: 0.5203 - precision_m: 0.4786 - recall_m: 0.5741 - val_loss: 0.7138 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=11657) Epoch 96/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6262 - accuracy: 0.6875 - f1_m: 0.7500 - precision_m: 0.7143 - recall_m: 0.7895
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6208 - accuracy: 0.6562 - f1_m: 0.7250 - precision_m: 0.6753 - recall_m: 0.7836
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6233 - accuracy: 0.6562 - f1_m: 0.7119 - precision_m: 0.6502 - recall_m: 0.7891
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6431 - accuracy: 0.6172 - f1_m: 0.6728 - precision_m: 0.6013 - recall_m: 0.7704
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6497 - accuracy: 0.6062 - f1_m: 0.6683 - precision_m: 0.5992 - recall_m: 0.7608
# 6/6 [==============================] - 2s 280ms/step - loss: 0.6495 - accuracy: 0.6111 - f1_m: 0.7235 - precision_m: 0.6660 - recall_m: 0.8006 - val_loss: 0.7019 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
# (train_mnist pid=11657) Epoch 97/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6622 - accuracy: 0.5312 - f1_m: 0.5946 - precision_m: 0.5000 - recall_m: 0.7333
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6753 - accuracy: 0.5625 - f1_m: 0.6306 - precision_m: 0.5455 - recall_m: 0.7490
# 3/6 [==============>...............] - ETA: 1s - loss: 0.6562 - accuracy: 0.6042 - f1_m: 0.6704 - precision_m: 0.5909 - recall_m: 0.7771
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6509 - accuracy: 0.6328 - f1_m: 0.6951 - precision_m: 0.6218 - recall_m: 0.7912
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6587 - accuracy: 0.6250 - f1_m: 0.6858 - precision_m: 0.6237 - recall_m: 0.7663
# 6/6 [==============================] - 2s 285ms/step - loss: 0.6606 - accuracy: 0.6235 - f1_m: 0.5715 - precision_m: 0.5198 - recall_m: 0.6386 - val_loss: 0.6768 - val_accuracy: 0.6316 - val_f1_m: 0.6316 - val_precision_m: 0.6667 - val_recall_m: 0.6000
# (train_mnist pid=11657) Epoch 98/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6446 - accuracy: 0.6250 - f1_m: 0.7000 - precision_m: 0.6087 - recall_m: 0.8235
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6507 - accuracy: 0.6094 - f1_m: 0.6988 - precision_m: 0.6453 - recall_m: 0.7689
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6494 - accuracy: 0.6250 - f1_m: 0.6945 - precision_m: 0.6407 - recall_m: 0.7626
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6456 - accuracy: 0.6094 - f1_m: 0.6679 - precision_m: 0.6121 - recall_m: 0.7386
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6519 - accuracy: 0.6000 - f1_m: 0.6643 - precision_m: 0.6027 - recall_m: 0.7438
# 6/6 [==============================] - 2s 279ms/step - loss: 0.6536 - accuracy: 0.5988 - f1_m: 0.5536 - precision_m: 0.5023 - recall_m: 0.6199 - val_loss: 0.6797 - val_accuracy: 0.5789 - val_f1_m: 0.6364 - val_precision_m: 0.5833 - val_recall_m: 0.7000
# (train_mnist pid=11657) Epoch 99/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6399 - accuracy: 0.6562 - f1_m: 0.7027 - precision_m: 0.6500 - recall_m: 0.7647
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6258 - accuracy: 0.6562 - f1_m: 0.7172 - precision_m: 0.6511 - recall_m: 0.7990
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6632 - accuracy: 0.5938 - f1_m: 0.6583 - precision_m: 0.6192 - recall_m: 0.7081
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6816 - accuracy: 0.5547 - f1_m: 0.6114 - precision_m: 0.5755 - recall_m: 0.6561
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6862 - accuracy: 0.5625 - f1_m: 0.6188 - precision_m: 0.5747 - recall_m: 0.6749
# 6/6 [==============================] - 2s 274ms/step - loss: 0.6872 - accuracy: 0.5617 - f1_m: 0.5157 - precision_m: 0.4789 - recall_m: 0.5624 - val_loss: 0.6782 - val_accuracy: 0.6316 - val_f1_m: 0.6316 - val_precision_m: 0.6667 - val_recall_m: 0.6000
# (train_mnist pid=11657) Epoch 100/100
# 1/6 [====>.........................] - ETA: 1s - loss: 0.6762 - accuracy: 0.6250 - f1_m: 0.6471 - precision_m: 0.6875 - recall_m: 0.6111
# 2/6 [=========>....................] - ETA: 1s - loss: 0.6753 - accuracy: 0.6094 - f1_m: 0.6569 - precision_m: 0.6264 - recall_m: 0.7118
# 3/6 [==============>...............] - ETA: 0s - loss: 0.6659 - accuracy: 0.6354 - f1_m: 0.6786 - precision_m: 0.6583 - recall_m: 0.7153
# 4/6 [===================>..........] - ETA: 0s - loss: 0.6650 - accuracy: 0.6250 - f1_m: 0.6661 - precision_m: 0.6312 - recall_m: 0.7198
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6640 - accuracy: 0.6187 - f1_m: 0.6662 - precision_m: 0.6288 - recall_m: 0.7203
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name          </th><th style="text-align: right;">  accuracy</th><th>date               </th><th>done  </th><th>episodes_total  </th><th>experiment_id                   </th><th>experiment_tag                                                                                          </th><th>hostname    </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">    loss</th><th>node_ip   </th><th style="text-align: right;">  pid</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th>trial_id  </th><th style="text-align: right;">  val_accuracy</th><th style="text-align: right;">  val_loss</th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_62f9ecf6</td><td style="text-align: right;">  0.493827</td><td>2022-11-17_16-14-05</td><td>True  </td><td>                </td><td>30cbca9122bf418b87a907a014b97023</td><td>1_conv_block1_filters=8,dropout_rate=0.3000,fc1_units=16,fc_layer_type=dense,lr=0.0100,pool_type=average</td><td>2e520a388c73</td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.743026</td><td>172.28.0.2</td><td style="text-align: right;">11657</td><td style="text-align: right;">             197.739</td><td style="text-align: right;">           197.739</td><td style="text-align: right;">       197.739</td><td style="text-align: right;"> 1668701645</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>62f9ecf6  </td><td style="text-align: right;">      0.473684</td><td style="text-align: right;">  0.698097</td><td style="text-align: right;">   0.00349307</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2022-11-17 16:14:05,472	INFO tune.py:778 -- Total run time: 202.49 seconds (202.33 seconds for the tuning loop).
# 6/6 [==============================] - 2s 286ms/step - loss: 0.6618 - accuracy: 0.6235 - f1_m: 0.7219 - precision_m: 0.6907 - recall_m: 0.7669 - val_loss: 0.8158 - val_accuracy: 0.5263 - val_f1_m: 0.6897 - val_precision_m: 0.5263 - val_recall_m: 1.0000
